# %% [markdown]
# # Load time scores from database

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pymysql as mdb
plt.rcParams['figure.figsize'] = 5,5

# %%
db = mdb.connect('localhost', 'root', '', 'insight')
with db:
    cur = db.cursor(mdb.cursors.DictCursor)
    cur.execute("SELECT * FROM flickr_clusters_nyc2")
    scores =cur.fetchall()
scores = pd.DataFrame(scores)
time_axis = np.linspace(0,24,49)
time_axis = time_axis[:-1]
hour_keys = [str(x) for x in  np.linspace(0,24,49)]
hour_keys = hour_keys[:-1]

scores['nycscore'] = scores['nphotos_nyc']/scores['nphotos']
scores2 = scores.sort('nycscore',ascending=False)
scores2[['lat','lng','nycscore']].head(n=10)
# Out:
#         lat      lng  nycscore
# 56  40.7245 -74.0455  0.921271
# 17  40.7487 -73.9197  0.848485
# 36  40.6925 -73.9659  0.695697
# 68  40.7258 -73.9803  0.639427
# 37  40.7042 -73.9867  0.607316
# 19  40.7947 -73.9719  0.598177
# 28  40.6736 -73.9917  0.590810
# 13  40.7025 -73.9886  0.564995
# 60  40.6828 -73.9757  0.552184
# 63  40.7178 -73.9578  0.529751

# %%
# Look at the different time scores for the different locations saved in sql
db = mdb.connect('localhost', 'root', '', 'insight')
with db:
    cur = db.cursor(mdb.cursors.DictCursor)
    cur.execute("SELECT * FROM flickr_clusters_nyc2_nycusers")
    scores_nyc = cur.fetchall()
    cur.execute("SELECT * FROM flickr_clusters_nyc2_outusers")
    scores_out = cur.fetchall()
    cur.execute("SELECT * FROM flickr_clusters_nyc2")
    scores =cur.fetchall()

scores_nyc = pd.DataFrame(scores_nyc)
scores_out = pd.DataFrame(scores_out)
scores = pd.DataFrame(scores)
scores = scores.sort('nphotos',ascending=False)
time_axis = np.linspace(0,24,49)
time_axis = time_axis[:-1]

hour_keys = [str(x) for x in  np.linspace(0,24,49)]
hour_keys = hour_keys[:-1]

fig = plt.figure(figsize=(16,16))
for i in range(71):#scores.shape[0]
    ax = fig.add_subplot(9,8,i+1)
    #plt.plot(time_axis, scores_nyc.ix[i][hour_keys]*100,'b')
    #plt.plot(time_axis, scores_out.ix[i][hour_keys]*100,'r')
    plt.plot(time_axis, scores.ix[i][hour_keys]*100,'k')
    #print scores.ix[i][['index','lat','lng']].values
    plt.ylim(ymin=0)
    plt.title('%d'%i)
    #print '%s: %s,%s'%(i, scores['lat'][i], scores['lng'][i])
#fig.set_size_inches(16,16)
#plt.savefig('time_score.png',dpi=100)

# %%
scores[hour_keys].divide(scores[hour_keys].max(axis=1), axis=0).ix[range(72)].head()
#scores.ix[0][hour_keys]
# Out:
#         0.0       0.5       1.0       1.5       2.0       2.5       3.0  \
# 0  0.910972  0.957191  1.000000  0.944421  0.913975  0.916028  0.957507
# 1  0.784610  0.750506  0.838780  0.860368  0.849463  0.745047  0.673005
# 2  0.746304  0.763520  0.737870  0.779220  0.821260  1.000000  0.871561
# 3  0.775408  0.821138  0.855948  0.862187  0.830249  0.936932  0.961738
# 4  0.407250  0.460536  0.449637  0.565666  0.556645  0.745126  0.679506
#
#         3.5       4.0       4.5    ...         19.0      19.5      20.0  \
# 0  0.977941  0.863318  0.793964    ...     0.785862  0.789166  0.810676
# 1  0.690808  0.697683  0.788111    ...     0.878607  0.905151  0.798239
# 2  0.820114  0.696193  0.853147    ...     0.667818  0.656849  0.651824
# 3  1.000000  0.919589  0.880627    ...     0.703004  0.712375  0.712035
# 4  0.799399  0.726463  0.770941    ...     0.587505  0.538949  0.480066
#
#        20.5      21.0      21.5      22.0      22.5      23.0      23.5
# ...

# %%
# clustering to determine location types 
from sklearn import decomposition
from mpl_toolkits.mplot3d import Axes3D
np.random.seed(5)

#data = scores[hour_keys].values
#data = scores[hour_keys].ix[range(72)].values
data = scores[hour_keys].divide(scores[hour_keys].max(axis=1), axis=0).ix[range(72)].values
latlng = scores[['index','lat','lng']].ix[range(72)].values
pca = decomposition.PCA(n_components=3)
pca.fit(data)
print(pca.explained_variance_ratio_) 
X = pca.transform(data)

fig = plt.figure(1, figsize=(5, 5))
scatter(X[:, 0], X[:, 1])
ind = 10
#plt.plot(X[ind,0], X[ind,1],'or')
# plt.clf()
# ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
# ax.scatter(X[:, 0], X[:, 1], X[:, 2], cmap=plt.cm.spectral)
plt.show()
sorted_inds = X[:,1].argsort()
print sorted_inds # lowest to highest
# 12=moma, rockefeller, prince street, river cafe 
#plt.plot(time_axis, data*100,'k')
for btm_pc in sorted_inds[:5]:
    plt.plot(time_axis,data[btm_pc,:])
    print latlng[btm_pc,:]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-c7d24a0eca89> in <module>()
#       9 latlng = scores[['index','lat','lng']].ix[range(72)].values
#      10 pca = decomposition.PCA(n_components=3)
# ---> 11 pca.fit(data)
#      12 print(pca.explained_variance_ratio_)
#      13 X = pca.transform(data)
#
# /usr/local/lib/python2.7/site-packages/sklearn/decomposition/pca.pyc in fit(self, X, y)
#     223             Returns the instance itself.
#     224         """
# --> 225         self._fit(X)
#     226         return self
#     227
#
# /usr/local/lib/python2.7/site-packages/sklearn/decomposition/pca.pyc in _fit(self, X)
#     267             requested.
#     268         """
# --> 269         X = array2d(X)
#     270         n_samples, n_features = X.shape
#     271         X = as_float_array(X, copy=self.copy)
#
# ...

# %%
import sys, os 
sys.path.append(os.path.abspath('flask_site/app/'))
from flickr_sites import *

# which locations have the biggest difference between nyc and nonnyc users
init_loc = [40.74844,-73.985664]
centroids_full = get_centroids_timescore_sql(db,init_loc,maxdist=0.5,num=200)
centroids_full = pd.DataFrame(centroids_full)
centroids_full['nycscore'] = centroids_full['nphotos_nyc'] / centroids_full['nphotos']
centroids_full = centroids_full.sort('nycscore',ascending=False, kind='mergesort')
centroids_full[['lat','lng']].head(n=20)
# Out:
#         lat      lng
# 60  40.7245 -74.0455
# 61  40.7487 -73.9197
# 57  40.6925 -73.9659
# 28  40.7258 -73.9803
# 49  40.7042 -73.9867
# 55  40.7947 -73.9719
# 63  40.6736 -73.9917
# 52  40.7025 -73.9886
# 62  40.6828 -73.9757
# 44  40.7178 -73.9578
# 48  40.7044 -73.9903
# 19  40.7292 -73.9883
# 50  40.7032 -73.9905
# 40  40.7192 -73.9617
# 64  40.6707 -73.9660
# 24  40.7282 -73.9910
# 14  40.7317 -73.9894
# 42  40.7218 -73.9577
# 23  40.7296 -73.9937
# 69  40.7569 -73.8460

# %%
# looking visiting duration 
with db:
    cur = db.cursor(mdb.cursors.DictCursor)
    cmd = "SELECT ClusterId, lat, lng, Dur FROM flickr_clusters_nyc2_visitdur JOIN flickr_clusters_nyc2 \
    ON flickr_clusters_nyc2_visitdur.ClusterId = flickr_clusters_nyc2.index" 
    cur.execute(cmd)
    centroids = cur.fetchall()
centroids = pd.DataFrame(centroids)
centroids['Dur_hour'] = centroids['Dur']/3600.
result = centroids.sort(['Dur'], ascending=False)
result.head(n=10)
# Out:
#     ClusterId    Dur      lat      lng  Dur_hour
# 17         17  10056  40.7487 -73.9197  2.793333
# 31         31   7664  40.7575 -74.0023  2.128889
# 47         47   7476  40.6517 -73.7159  2.076667
# 36         36   7267  40.6925 -73.9659  2.018611
# 45         45   6514  40.8295 -73.9267  1.809444
# 65         65   6494  40.7497 -73.8467  1.803889
# 41         41   5695  40.7569 -73.8460  1.581944
# 32         32   5631  40.6871 -73.9912  1.564167
# 56         56   5382  40.7245 -74.0455  1.495000
# 58         58   5256  40.7523 -73.9936  1.460000
