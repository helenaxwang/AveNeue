# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json, os
import seaborn as sns
import pymysql as mdb
plt.rcParams['figure.figsize'] = 5,5

# %%
# import everything into a list directly from the raw json files 
flickr_yahoo_path = 'flickr_yahoodata'
photos = []
for fnum in range(10):
    json_file_name = "yfcc100m_dataset-%d_nyc.json" % fnum
    print json_file_name
    with open(os.path.join(flickr_yahoo_path,json_file_name)) as fp:
        photos.extend(json.load(fp))
# Out:
# yfcc100m_dataset-0_nyc.json
# yfcc100m_dataset-1_nyc.json
# yfcc100m_dataset-2_nyc.json
# yfcc100m_dataset-3_nyc.json
# yfcc100m_dataset-4_nyc.json
# yfcc100m_dataset-5_nyc.json
# yfcc100m_dataset-6_nyc.json
# yfcc100m_dataset-7_nyc.json
# yfcc100m_dataset-8_nyc.json
# yfcc100m_dataset-9_nyc.json

# %%
# convert into a data frame 
photo_df = pd.DataFrame(photos)
photo_df.head()
# Out:
#   accuracy             date_taken date_uploaded  \
# 0       15  2012-05-28 00:23:30.0    1338233199
# 1       15  2006-07-21 11:05:36.0    1153597828
# 2       13  2006-08-04 20:40:28.0    1154749228
# 3       15  2008-08-08 08:37:00.0    1218657922
# 4       16  2012-04-23 14:39:57.0    1347566092
#
#                                          description  \
# 0
# 1        Hackers+And+Academia+-+Room+A+-+Friday+1100
# 2
# 3  The+yellow+tube+is+the+jasmine+custard%2C+and+...
# 4  Empire+State+Building+%3Ca+href%3D%22http%3A%2...
#
#                         device  \
# 0  Canon+EOS+DIGITAL+REBEL+XSi
# 1   Canon+EOS+DIGITAL+REBEL+XT
# 2
# 3      Canon+PowerShot+A710+IS
# 4             PENTAX+Optio+V20
#
#                                         download_url extension_orig farm_id  \
# 0  http://farm8.staticflickr.com/7231/7289030198_...            jpg       8
# 1  http://farm1.staticflickr.com/75/195575666_a35...            jpg       1
# ...

# %%
# limit data by a certain radius 
init_loc = (40.74844,-73.985664) # empire state building, latitude/longitude
radius = 0.005
idx = sqrt((photo_df['lng']-init_loc[1])**2 + (photo_df['lat']-init_loc[0])**2) < radius
# plot data 
plt.plot(photo_df['lng'][idx], photo_df['lat'][idx],'.k')

# %%
# cluster to find centroids 
#from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
data = photo_df[['lng','lat']][idx].values
#estimator = KMeans(init='k-means++', n_clusters=10, n_init=10)
#estimator.fit(data)
#centroids = estimator.cluster_centers_
#plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', s=169, linewidths=2, color='r', zorder=10)
estimator = DBSCAN(eps=0.0005, min_samples=1000)
estimator.fit(data)

core_samples_mask = np.zeros_like(estimator.labels_, dtype=bool)
core_samples_mask[estimator.core_sample_indices_] = True
labels = estimator.labels_
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

# Black removed and is used for noise instead.
unique_labels = set(labels)
centroids = []
colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_labels)))
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = 'k'

    class_member_mask = (labels == k)

    xy = data[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=4)
    if k != -1:
        centroid = xy.mean(axis=0)
        centroids.append(centroid)
        plt.plot(centroid[0],centroid[1],'o',markersize=8)

    xy = data[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=2)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()

# %%
from sklearn.cluster import MeanShift, estimate_bandwidth
bandwidth = estimate_bandwidth(data, quantile=0.4, n_samples=100)
ms = MeanShift(bandwidth=bandwidth, cluster_all=False)
ms.fit(data)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

unique_labels = np.unique(labels)
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
print("number of estimated clusters : %d" % n_clusters_)

colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_labels)))
for k, col in zip(unique_labels, colors):
    if k == -1: # Black used for noise.
        col = 'k'

    class_member_mask = (labels == k)

    xy = data[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=4)
    
    if k != -1:
        plt.plot(cluster_centers[k][0],cluster_centers[k][1],'o',markersize=8)

    xy = data[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=2)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# number of estimated clusters : 2

# %%
# Out:
# array([[-73.98556044,  40.74849203],
#        [-73.98815994,  40.75018243],
#        [-73.98763369,  40.74522827],
#        [-73.98324889,  40.75004715],
#        [-73.98567435,  40.75191132]])

# %%
# remove bad time points and index by time 
# check for date time convertable 
temp = pd.to_datetime(photo_df['date_taken'][0])
badidx = np.zeros(shape = (photo_df.shape[0]))
for idx,date in enumerate(photo_df['date_taken']):
    if type(pd.to_datetime(date)) != type(temp):
        print idx,date
        badidx[idx] = 1
# Out:
# 36107 2555-08-21 12:08:30.0
# 70274
#  null
# 125434
#  2555-08-21 12:14:40.0
# 209427
#  2555-08-21 12:10:52.0
# 416032
#  4501-01-01 00:00:00.0
# 495268
#  2555-08-21 12:14:23.0
# 510748
#  2555-08-21 12:09:07.0
# 649078
#  2555-08-21 12:08:52.0
# 674958
#  2555-08-20 21:24:42.0
# 760085
#  2555-08-21 12:09:21.0
# 859581
#  2555-08-21 12:16:36.0
# 921206
#  2555-08-21 12:10:26.0
# 931341
#  2555-08-21 07:57:26.0
# 1064992
#  2555-08-21 12:14:05.0

# %%
# restrict data frame 
photos2 = photo_df.ix[badidx == 0]
# convert to date time and reset index
photos2.index = pd.to_datetime(photos2['date_taken'])
# get photos within reasonable window
photos2 = photos2.ix['2009':'2015'] #802295
print 'total number of photos: ', len(photos2)
#photos2 = photos2.set_index('date_taken')
# Out:
# total number of photos:  802295

# %%
# load attractions from database
import pymysql as mdb
db = mdb.connect('localhost', 'root', '', 'insight')
with db:
    cur = db.cursor(mdb.cursors.DictCursor)
    cmd = "SELECT * FROM tripomatic_latlng "
    cur.execute(cmd)
    attractions = cur.fetchall()
attractions = pd.DataFrame(attractions)
attractions.head()
# Out:
#    Entry  Id  bounds_ne_lat  bounds_ne_lng  bounds_sw_lat  bounds_sw_lng  \
# 0      1   0            NaN            NaN            NaN            NaN
# 1      2   1      40.710099     -74.010344      40.709378     -74.011387
# 2      3   1            NaN            NaN            NaN            NaN
# 3      4   1            NaN            NaN            NaN            NaN
# 4      5   2      40.755829     -74.178411      40.755824     -74.178428
#
#      loc_lat    loc_lng  viewport_ne_lat  viewport_ne_lng  viewport_sw_lat  \
# 0  40.708193 -74.038212        40.709542       -74.036863        40.706844
# 1  40.709699 -74.010824        40.711087       -74.009516        40.708390
# 2  40.709614 -74.010953        40.710963       -74.009604        40.708265
# 3  40.708791 -74.009604        40.710140       -74.008255        40.707442
# 4  40.755824 -74.178411        40.757176       -74.177070        40.754478
#
#    viewport_sw_lng
# 0       -74.039561
# 1       -74.012214
# ...

# %%
# load from database - skip if you already loaded from json. otherwise might be slow
db = mdb.connect('localhost', 'root', '', 'insight')
with db:
    cur = db.cursor(mdb.cursors.DictCursor)
    cmd = "SELECT * FROM flickr_yahoo_nyc "
    cur.execute(cmd)
    photos = cur.fetchall()
# convert into a data frame 
photos2= pd.DataFrame(photos)

from datetime import datetime
#from dateutil.parser import parse
photos2.index = pd.to_datetime(photos2['date_taken'])
print photos2.head()
# Out:
#                               Id      Lat      Lng  accuracy  \
# date_taken
# 2013-09-29 10:30:57  10000004823  40.6977 -73.9907        16
# 2013-09-22 20:50:11  10000076194  40.7179 -73.9657        13
# 2013-09-29 10:35:07  10000080143  40.6832 -73.9737        16
# 2013-09-29 08:41:09  10000121956  40.7012 -73.9847        16
# 2013-09-27 16:23:44  10000134085  40.7560 -73.9890        15
#
#                              date_taken date_uploaded  \
# date_taken
# 2013-09-29 10:30:57 2013-09-29 10:30:57    1380465057
# 2013-09-22 20:50:11 2013-09-22 20:50:11    1380465703
# 2013-09-29 10:35:07 2013-09-29 10:35:07    1380465307
# 2013-09-29 08:41:09 2013-09-29 08:41:09    1380465669
# 2013-09-27 16:23:44 2013-09-27 16:23:44    1380465887
#
#                                               device  farm_id  \
# date_taken
# 2013-09-29 10:30:57                                         3
# 2013-09-22 20:50:11  PENTAX+Corporation+PENTAX+K100D        8
# ...

# %%
# just work with the series
# date_series = pd.Series(np.ones(photos2.shape[0]), index =photos2['date_taken'])
# group by hours 
#year_hour_means = date_series2.groupby(lambda x: (x.year, x.hour)).count()
#year_hour_means.index = pd.MultiIndex.from_tuples(year_hour_means.index, names=['year', 'hour'])
# hour_means = date_series2.groupby(lambda x: x.hour).count()

# %% [markdown]
# # Looking at time plots

# %%
# round to the nearest hour or whatever other interval 
# http://stackoverflow.com/questions/24479577/pandas-timestamp-index-rounding-to-the-nearest-5th-minute
do_nyc_users = False
nsround = 30*60*1000000000   # 60 minutes in nanoseconds

photos2.index = pd.DatetimeIndex(((photos2.index.astype(np.int64) // nsround ) * nsround))
# do the same thing for the date_taken column
photos2['date_taken'] = pd.DatetimeIndex(((pd.to_datetime(photos2.date_taken).astype(np.int64) // nsround) * nsround))
photos2 = photos2.drop_duplicates(['user_id','date_taken'])

# divide up into nyc and non nyc users 
if do_nyc_users:
    photos_nyc = photos2.ix[isnyc]
    photos_nonyc = photos2.ix[isnyc==False]
    print 'photos_nyc', photos_nyc.shape

    photos_nyc = photos_nyc.drop_duplicates(['user_id','date_taken'])
    photos_nonyc = photos_nonyc.drop_duplicates(['user_id','date_taken'])

    print photos2.shape[0], photos_nyc.shape[0], photos_nonyc.shape[0]
photos2.head()
# Out:
#                     accuracy          date_taken date_uploaded  \
# 2012-05-28 00:00:00       15 2012-05-28 00:00:00    1338233199
# 2012-04-23 14:30:00       16 2012-04-23 14:30:00    1347566092
# 2012-11-04 09:00:00       16 2012-11-04 09:00:00    1352050137
# 2010-10-09 18:30:00       14 2010-10-09 18:30:00    1287002963
# 2012-02-25 12:00:00       16 2012-02-25 12:00:00    1330226655
#
#                                                            description  \
# 2012-05-28 00:00:00
# 2012-04-23 14:30:00  Empire+State+Building+%3Ca+href%3D%22http%3A%2...
# 2012-11-04 09:00:00
# 2010-10-09 18:30:00
# 2012-02-25 12:00:00  %3Ca+href%3D%22http%3A%2F%2Fen.wikipedia.org%2...
#
#                                           device  \
# 2012-05-28 00:00:00  Canon+EOS+DIGITAL+REBEL+XSi
# 2012-04-23 14:30:00             PENTAX+Optio+V20
# 2012-11-04 09:00:00
# 2010-10-09 18:30:00   Canon+EOS+DIGITAL+REBEL+XT
# 2012-02-25 12:00:00               Motorola+Droid
#
# ...

# %%
# test some things 
photos2['user_id'].groupby(lambda x: (x.hour, x.minute)).count()
print photos2.shape[0]#, photos_nyc.shape[0], photos_nonyc.shape[0]
#146753 + 106826
# Out:
# 253579

# %%
# get the hour mean - do it by hour - skip!
# http://stackoverflow.com/questions/16967165/getting-the-average-of-a-certain-hour-on-weekdays-over-several-years-in-a-pandas 
def get_hour_mean(photo_df, loc, radius=0.005, normalize=False):
    idx = np.sqrt((photo_df['lat']-loc[0])**2 + (photo_df['lng']-loc[1])**2) < radius
    print 'number of photos near location ', sum(idx)
    hour_mean = photo_df.user_id[idx].groupby(lambda x: x.hour).count()
    if normalize:
        hour_mean = hour_mean / float(photo_df.user_id[idx].count())
    return hour_mean

# compute the hour mean for all of nyc
hour_all_normalized = photos2.user_id.groupby(lambda x: x.hour).count()/photos2.user_id.count()
hour_all = photos2.user_id.groupby(lambda x: x.hour).count()

time_axis = range(24)
plt.plot(time_axis, hour_all)

# %%
loc = [40.6832,-73.9737]
#idx = np.sqrt((photos2['lat']-loc[0])**2 + (photos2['lng']-loc[1])**2) < 0.005
idx = photos2['user_name'] == 'atlanticyardswebcam04'
print 'number of photos near location ', sum(idx)
loc_density = get_hour_mean(photos2,loc)#/hour_all
plt.plot(time_axis, loc_density)
print sum(photos2.ix[idx]['user_name'] == 'atlanticyardswebcam04')
#photos2.ix[photos2['user_name'] == 'atlanticyardswebcam04']['page_url'].head(n=10)
# Out:
# number of photos near location  12349
# number of photos near location  13519
# 12349

# %%
# getting photo favorites for each hour at a location 
# define the function 
import pymysql as mdb
db = mdb.connect('localhost', 'root', '', 'insight')
def get_favcounts_sql(db,loc,radius=0.005):
    with db:
        cur = db.cursor(mdb.cursors.DictCursor)
        cmd = "SELECT flickr_favorites.Id,Fav,Lat,Lng, date_taken FROM flickr_yahoo_nyc JOIN flickr_favorites \
        ON flickr_yahoo_nyc.Id = flickr_favorites.Id\
        WHERE ( POWER(lat - (%s), 2) + POWER(lng - (%s), 2) ) < POWER(%s, 2)" % \
        (loc[0], loc[1], radius)
        #print cmd
        cur.execute(cmd)
        results = cur.fetchall()
    print len(results)
    results = pd.DataFrame(results)
    # round to the nearest half hour
    results.index = pd.DatetimeIndex(((results.date_taken.astype(np.int64) // nsround ) * nsround))
    # get the average favorite counts
    #results = results.Fav[results.Fav>0].groupby(lambda x: (x.hour, x.minute)).count()
    return results

# test case 
init_loc = [40.74844,-73.985664]
results = get_favcounts_sql(db,init_loc,radius=0.01)
results.head()
# Out:
# 56352
#                      Fav           Id      Lat      Lng          date_taken
# 2013-09-27 16:00:00    0  10000134085  40.7560 -73.9890 2013-09-27 16:23:44
# 2013-09-29 10:00:00    1  10000840654  40.7528 -73.9772 2013-09-29 10:21:57
# 2013-04-08 07:30:00    0  10003743714  40.7550 -73.9858 2013-04-08 07:33:02
# 2013-04-08 08:00:00    0  10003748675  40.7458 -73.9792 2013-04-08 08:03:34
# 2013-04-06 09:00:00    0  10003761465  40.7482 -73.9850 2013-04-06 09:28:41

# %%
# get the mean at some smaller interval (a generalized case of above)
def get_hour_mean(photo_df, loc, radius=0.005, normalize=False):
    idx = np.sqrt((photo_df['lat']-loc[0])**2 + (photo_df['lng']-loc[1])**2) < radius
    print 'number of photos near location ', sum(idx)
    hour_mean = photo_df.user_id[idx].groupby(lambda x: (x.hour, x.minute)).count()
    if normalize:
        hour_mean = hour_mean / float(photo_df.user_id[idx].count())
    return hour_mean

def get_hour_weightedmean(photo_df, loc, radius=0.005):
    idx = np.sqrt((photo_df['lat']-loc[0])**2 + (photo_df['lng']-loc[1])**2) < radius
    print 'number of photos near location ', sum(idx)
    hour_mean = photo_df.Fav[idx].groupby(lambda x: (x.hour, x.minute)).sum()
    return hour_mean

# compute the hour mean for all of nyc
hour_all_normalized = photos2.user_id.groupby(lambda x: (x.hour, x.minute)).count()/photos2.user_id.count()
hour_all = photos2.user_id.groupby(lambda x: (x.hour, x.minute)).count()
print photos2.shape

# compute the hour mean for local users 
if do_nyc_users:
    hour_all_nyc = photos_nyc.user_id.groupby(lambda x: (x.hour, x.minute)).count()
    hour_all_nonyc = photos_nonyc.user_id.groupby(lambda x: (x.hour, x.minute)).count()
    print sum(hour_all), sum(hour_all_nyc), sum(hour_all_nonyc)

# compute the hour mean weighted by favorites 
#hour_all_favweight = photos2.Fav.groupby(lambda x: (x.hour, x.minute)).sum()
if do_nyc_users:
    hour_all_favweight_nyc = photos_nyc.Fav.groupby(lambda x: (x.hour, x.minute)).sum()
    hour_all_favweight_nonnyc = photos_nonyc.Fav.groupby(lambda x: (x.hour, x.minute)).sum()

# compute favorites of all of new york city 
#favorites_all = get_favcounts_sql(db, [40.74844,-73.985664], radius=1.0)
#favorites_all = favorites_all.Fav[favorites_all.Fav>0].groupby(lambda x: (x.hour, x.minute)).count()

time_axis = np.linspace(0,24,len(hour_all)+1)
time_axis = time_axis[:-1]

fig = plt.figure(figsize=(6,4))
plt.plot(time_axis,hour_all)
# Out:
# (253579, 24)

# %%
photos2.head()
# Out:
#                     accuracy          date_taken date_uploaded  \
# 2012-05-28 00:00:00       15 2012-05-28 00:00:00    1338233199
# 2012-04-23 14:30:00       16 2012-04-23 14:30:00    1347566092
# 2012-11-04 09:00:00       16 2012-11-04 09:00:00    1352050137
# 2010-10-09 18:30:00       14 2010-10-09 18:30:00    1287002963
# 2012-02-25 12:00:00       16 2012-02-25 12:00:00    1330226655
#
#                                                            description  \
# 2012-05-28 00:00:00
# 2012-04-23 14:30:00  Empire+State+Building+%3Ca+href%3D%22http%3A%2...
# 2012-11-04 09:00:00
# 2010-10-09 18:30:00
# 2012-02-25 12:00:00  %3Ca+href%3D%22http%3A%2F%2Fen.wikipedia.org%2...
#
#                                           device  \
# 2012-05-28 00:00:00  Canon+EOS+DIGITAL+REBEL+XSi
# 2012-04-23 14:30:00             PENTAX+Optio+V20
# 2012-11-04 09:00:00
# 2010-10-09 18:30:00   Canon+EOS+DIGITAL+REBEL+XT
# 2012-02-25 12:00:00               Motorola+Droid
#
# ...

# %%
# add a new column with favorites used for weighting 
# -------------------------------------------------
# get all the flicker favorites for subsampled photo data set from the database 
# with db:
#     cur = db.cursor(mdb.cursors.DictCursor)
#     cmd = "SELECT * FROM flickr_yahoo_nyc2 LEFT JOIN flickr_favorites ON flickr_yahoo_nyc2.Id = flickr_favorites.Id"
#     cur.execute(cmd)
#     results = cur.fetchall()
# results = pd.DataFrame(results)
# print results.shape
db = mdb.connect('localhost', 'root', '', 'insight')
with db:
    cur = db.cursor(mdb.cursors.DictCursor)
    cmd = "SELECT * FROM flickr_favorites"
    cur.execute(cmd)
    results = cur.fetchall()
results = pd.DataFrame(results)
print results.shape

# fill the missing values with 0
results['Fav'] = results['Fav'].fillna(0)

del photos2['Fav']
results2 = results[['Fav','Id']]
results2.columns = ['Fav','id']
temp = pd.merge(photos2,results2,on='id',how='left') # merge photos2 and results
print sum(temp['Fav'].notnull()) # number of photos with favorite counts that our subsampled data sets
temp['Fav'] = temp['Fav'].fillna(0)
photos2['Fav'] = temp['Fav'].values

print sum(photos2['Fav'].notnull())
photos2['Fav'] = 1+np.log(photos2['Fav']+1) # add 1 so that baseline of 0 is a weight of 1 
plt.hist(photos2['Fav'])
# Out:
# (323759, 2)
# 108745
# 253579
# (array([  2.32196000e+05,   1.38360000e+04,   3.85900000e+03,
#           1.91200000e+03,   9.48000000e+02,   4.62000000e+02,
#           1.92000000e+02,   1.00000000e+02,   5.70000000e+01,
#           1.70000000e+01]),
#  array([ 1.        ,  1.60161572,  2.20323143,  2.80484715,  3.40646286,
#          4.00807858,  4.6096943 ,  5.21131001,  5.81292573,  6.41454144,
#          7.01615716]),
#  <a list of 10 Patch objects>)

# %%
# plot stuff
fig = plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
plt.plot(time_axis,hour_all)
if do_nyc_users:
    plt.plot(time_axis, hour_all_nyc,'r')
    plt.plot(time_axis, hour_all_nonyc,'g')
plt.title('photo density nyc')

plt.subplot(1,2,2)
plt.plot(time_axis,hour_all_favweight)
plt.title('photo density weighted by favorites nyc')
if do_nyc_users:
    plt.plot(time_axis, hour_all_favweight_nyc,'r')
    plt.plot(time_axis, hour_all_favweight_nonnyc,'g')

# plt.subplot(1,3,2)
# plt.plot(time_axis,favorites_all)
# plt.title('mean favorites nyc')

# plt.subplot(1,3,3)
# plt.plot(time_axis,favorites_all/hour_all)
# plt.title('mean favorites / photo density nyc')

# %%
# divide photos up by weekday or weekend 
doFavorites = 0
photos2['dayofweek'] = photos2.index.dayofweek

if doFavorites == 0: # plot raw photo count by weekend or weekday
    hour_all_weekday = photos2['user_id'][photos2['dayofweek']<5].groupby(lambda x: (x.hour, x.minute)).count()
    plt.plot(time_axis,hour_all_weekday,'r')
    hour_all_weekend = photos2['user_id'][photos2['dayofweek']>=5].groupby(lambda x: (x.hour, x.minute)).count()
    plt.plot(time_axis,hour_all_weekend,'g')
    
elif doFavorites == 1:  # get the count of photos with favorites greater than 0 
    favorites_all = get_favcounts_sql(db, [40.74844,-73.985664], radius=1.0)
   
    favorites_all['dayofweek'] = favorites_all.index.dayofweek
    fav_all_weekday = favorites_all['Id'][(favorites_all.dayofweek <5) & (favorites_all.Fav>0)].groupby(lambda x: (x.hour, x.minute)).count()
    plt.plot(time_axis,fav_all_weekday,'r')
    fav_all_weekend = favorites_all['Id'][(favorites_all.dayofweek >=5) & (favorites_all.Fav>0)].groupby(lambda x: (x.hour, x.minute)).count()
    plt.plot(time_axis,fav_all_weekend,'g')

    favorites_all = favorites_all.Fav[favorites_all.Fav>0].groupby(lambda x: (x.hour, x.minute)).count()
    plt.plot(time_axis,favorites_all,'k')
    
elif doFavorites == 2: # plot weighted photo count
    hour_all_weekday = photos2['Fav'][photos2['dayofweek']<5].groupby(lambda x: (x.hour, x.minute)).sum()
    plt.plot(time_axis,hour_all_weekday,'r')
    hour_all_weekend = photos2['Fav'][photos2['dayofweek']>=5].groupby(lambda x: (x.hour, x.minute)).sum()
    plt.plot(time_axis,hour_all_weekend,'g')

# %%
# Plot a nice figure for slides 
fig = plt.figure(figsize=(4,2))
colors = [[63, 121, 204], [228, 65, 69], [116,183,74]]

# Add a subplot
ax = fig.add_subplot(111)
#init_loc7 = (40.753596,-73.983233)# byrant park
init_loc7 = (40.74844,-73.985664) # empire state building 
init_loc8 = (40.747992,-74.004765)# high line
allLocs = [init_loc7, init_loc8]
allLocNames = ['Byrant Park', 'High Line']
color = ['b','r']
for i,loc in enumerate(allLocs):
    hour_loc = get_hour_mean(photos2,loc, radius=0.005)/hour_all
    #hour_loc = get_hour_weightedmean(photos2,loc, radius=0.005) / hour_all_favweight
    hour_loc = movingaverage2(hour_loc,3)
    plt.plot(time_axis,hour_loc*100,color=np.array(colors[i])/255.,linewidth=4,label=allLocNames[i])

plt.xlim([0,24])
plt.ylim(ymin=0)
#plt.xlabel('Time of day (hour)',fontsize=18, fontname='sans-serif',weight='light')
#plt.ylabel('Normalized photo density (%)',fontsize=18, fontname='sans-serif', weight='light')
plt.xticks(range(0,25,4), fontsize=16, fontname='sans-serif')
plt.yticks(range(0,4), fontsize=16, fontname='sans-serif')
#plt.legend(loc='best',prop={'size':16})

#ax.patch.set_facecolor([1,1,1])
# Remove grid lines (dotted lines inside plot)
ax.grid(True)
# Remove plot frame
ax.set_frame_on(True)
ax.yaxis.grid()
# Pandas trick: remove weird dotted line on axis
#ax.lines[0].set_visible(True)
#fig.set_size_inches(6,4)
#savefig('bryantpark.eps', format='eps', bbox_inches='tight')
#plt.savefig('bryantpark.eps',format='eps', dpi=100)
# Out:
# number of photos near location  6192
# number of photos near location
#  3672

# %%
# Nice plot for one location divided by day 
fig = plt.figure(figsize=(4,2))
colors = sns.color_palette("Paired", 8)

ax = fig.add_subplot(111)
# time course by user locality 
#init_loc = (40.753596,-73.983233)# byrant park
#init_loc = (40.74844,-73.985664) # empire state building 
#init_loc = (40.758895, -73.985131) # time square
init_loc = (40.747992,-74.004765)# high line
# hour_loc_nyc   = get_hour_mean(photos_nyc,init_loc)/hour_all
# hour_loc_nonyc = get_hour_mean(photos_nonyc,init_loc)/hour_all
hour_loc_nyc   = get_hour_mean(photos_nyc,init_loc)/hour_all_nyc
hour_loc_nonyc = get_hour_mean(photos_nonyc,init_loc)/hour_all_nonyc
# percentage for each user base 
#hour_loc_all = get_hour_mean(photos2,loc)
#hour_loc_nyc = get_hour_mean(photos_nyc,init_loc)/hour_loc_all
#hour_loc_nonyc = get_hour_mean(photos_nonyc,init_loc)/hour_loc_all
# smooth and plot 
allLocs = [hour_loc_nyc, hour_loc_nonyc]
for i,loc in enumerate(allLocs):
    hour_loc = movingaverage2(allLocs[i],3)
    plt.plot(time_axis,hour_loc*100,color=colors[i+4],linewidth=4)

plt.xlim([0,24])
plt.ylim(ymin=0)
#plt.xlabel('Time of day (hour)',fontsize=18, fontname='sans-serif',weight='light')
#plt.ylabel('Normalized photo density (%)',fontsize=18, fontname='sans-serif', weight='light')
plt.xticks(range(0,25,4), fontsize=16, fontname='sans-serif')
plt.yticks(range(0,3), fontsize=16, fontname='sans-serif')
#plt.legend(loc='best',prop={'size':16})

#ax.patch.set_facecolor([1,1,1])
ax.yaxis.grid()
#fig.set_size_inches(6,4)
#savefig('highline.eps', format='eps', bbox_inches='tight')
# Out:
# number of photos near location  1704
# number of photos near location  1968

# %%
# now findout hour means for different locations 
import seaborn as sns
init_loc1 = (40.7359464,-73.9889084) # union square,  latitude/longitude
init_loc2 = (40.758895, -73.985131)  # time square
init_loc3 = (40.7307465,-73.9976182) # washington square park 
init_loc4 = (40.7176379,-73.9599521) # williamsburg
init_loc5 = (40.7115551,-73.9531715) # mcdougal street 
init_loc6 = (40.752726, -73.977229) # Grand Central
init_loc7 = (40.74844,-73.985664)   # empire state building 
init_loc8 = (40.747992,-74.004765)

normalize = False
smooth = True
doWeekend = True
doLocality = False
doFavorites = 0

# concate them together 
allLocs = [init_loc1, init_loc2, init_loc3, init_loc4, init_loc5, init_loc6, init_loc7, init_loc8]
allLocNames = ['Union Square', 'Time Square', 'Washington Square Park', \
               'Williamsburg', 'McDougal Street', 'Grand Central', 'Empire State Building', 'High Line']
#rcParams['figure.figsize'] = 6,4
fig = plt.figure(figsize=(14,4))
#colors = ['b','r','g','m','k']
color = 'k'
locidx = range(0,8)#range(5,6)
# 106826 146753

for i,loc in zip(locidx,allLocs[0:8]):
    #fig.suptitle(allLocNames[i], fontsize=14, fontweight='bold')
    #plt.subplot(2,4,i+1)
    ax = fig.add_subplot(2,4,i+1)
    
    if doFavorites == 0:
        hour_loc = get_hour_mean(photos2,loc,normalize=normalize)/hour_all
        if doWeekend: 
            #hour_loc2 = get_hour_mean(photos2,loc,radius=0.01,normalize=normalize)/hour_all
            hour_loc_weekday = get_hour_mean(photos2.ix[photos2['dayofweek']<5],loc,normalize=normalize)/hour_all_weekday
            hour_loc_weekend = get_hour_mean(photos2.ix[photos2['dayofweek']>=5],loc,normalize=normalize)/hour_all_weekend
        if doLocality:
            hour_loc_nyc = get_hour_mean(photos_nyc,loc,normalize=normalize)/hour_all_nyc
            hour_loc_nonyc = get_hour_mean(photos_nonyc,loc,normalize=normalize)/hour_all_nonyc
    
    elif doFavorites == 2:
        hour_loc = get_hour_weightedmean(photos2,loc)/hour_all_favweight
        if doWeekend: 
            hour_loc_weekday = get_hour_weightedmean(photos2.ix[photos2['dayofweek']<5],loc)/hour_all_weekday
            hour_loc_weekend = get_hour_weightedmean(photos2.ix[photos2['dayofweek']>=5],loc)/hour_all_weekend
        if doLocality:
            hour_loc_nyc = get_hour_weightedmean(photos_nyc,loc)/hour_all_favweight_nyc
            hour_loc_nonyc = get_hour_weightedmean(photos_nonyc,loc)/hour_all_favweight_nonnyc
            
    elif doFavorites == 1:
        favorites_loc = get_favcounts_sql(db, loc, radius=0.01)
        favorites_loc['dayofweek'] = favorites_loc.index.dayofweek

        favorites_loc_weekday = favorites_loc.Fav[(favorites_loc['Fav']>0) & (favorites_loc['dayofweek']<5)]\
        .groupby(lambda x: (x.hour, x.minute)).mean()/normalizer#/fav_all_weekday

        favorites_loc_weekend = favorites_loc.Fav[(favorites_loc['Fav']>0) & (favorites_loc['dayofweek']>=5)]\
        .groupby(lambda x: (x.hour, x.minute)).mean()/normalizer#/fav_all_weekend
        favorites_loc = favorites_loc.Fav[favorites_loc.Fav>0].groupby(lambda x: (x.hour, x.minute)).mean()/normalizer#/favorites_all
        
    if smooth:
        if doLocality:
            hour_loc_nyc = movingaverage2(hour_loc_nyc,3)
            hour_loc_nonyc = movingaverage2(hour_loc_nonyc,3)
        if doFavorites == 1: 
            favorites_loc = movingaverage2(favorites_loc,3)
            favorites_loc_weekday = movingaverage2(favorites_loc_weekday,3)
            favorites_loc_weekend = movingaverage2(favorites_loc_weekend,3)
        else:
            hour_loc = movingaverage2(hour_loc,3)
            #hour_loc2 = movingaverage2(hour_loc2,3)
        if doWeekend:
            hour_loc_weekday = movingaverage2(hour_loc_weekday,3)
            hour_loc_weekend = movingaverage2(hour_loc_weekend,3)
    
    if doLocality:
        plt.plot(time_axis,hour_loc_nyc,'r',linewidth=2)
        plt.plot(time_axis,hour_loc_nonyc,'g',linewidth=2)
    if doFavorites == 1:
        plt.plot(time_axis,favorites_loc,color,linewidth=2, label=allLocNames[i])
        plt.plot(time_axis,favorites_loc_weekday,'r',linewidth=2)
        plt.plot(time_axis,favorites_loc_weekend,'g',linewidth=2)
    #else:
        #plt.plot(time_axis,hour_loc,color,linewidth=2, label=allLocNames[i])
        #plt.plot(time_axis,hour_loc2,'r',linewidth=2, label=allLocNames[i])
    if doWeekend:
        plt.plot(time_axis,hour_loc_weekday*100,'r',linewidth=2)
        plt.plot(time_axis,hour_loc_weekend*100,'g',linewidth=2)
        
    plt.ylim(ymin=0)
    ymin, ymax = plt.ylim()
    plt.xticks(range(0,25,4), fontsize=16, fontname='sans-serif')
    plt.yticks(range(0,int(ymax)+1), fontsize=16, fontname='sans-serif')
    #plt.xlabel('Hour',fontsize=12)
    #plt.ylabel('Normalized photo density',fontsize=12)
    plt.title(allLocNames[i], fontsize=16, fontname='sans-serif')
    #plt.legend(loc='best')
    #fig.set_size_inches(6,4)
    plt.savefig('presentations/weekend.png',dpi=100)
# Out:
# number of photos near location  5495
# number of photos near location
#  3700
# number of photos near location
#  1795
# number of photos near location
#  11078
# number of photos near location
#  7596
# number of photos near location
#  3482
# number of photos near location
#  6042
# number of photos near location
#  3924
# number of photos near location
#  2118
# number of photos near location
#  3255
# number of photos near location
#  1683
# number of photos near location
#  1572
# number of photos near location
#  1295
# number of photos near location
#  715
# number of photos near location
#  580
# number of photos near location
#  5277
# number of photos near location
#  3821
# number of photos near location
#  1456
# number of photos near location
#  6192
# number of photos near location
#  4277
# number of photos near location
#  1915
# number of photos near location
#  3672
# number of photos near location
#  2155
# number of photos near location
#  1517

# %%
# look at the difference between local and nonlocals more closely 
fig = plt.figure(figsize=(18,8))
for i,loc in zip(locidx,allLocs[0:7]):
    plt.subplot(2,4,i+1)
    hour_loc_nyc = get_hour_mean(photos_nyc,loc,normalize=normalize)/normalizer/106826
    hour_loc_nonyc = get_hour_mean(photos_nonyc,loc,normalize=normalize)/normalizer/146753

    hour_loc_nyc2 = hour_loc_nyc/hour_all_nyc
    hour_loc_nonyc2 = hour_loc_nonyc/hour_all_nonyc

    if smooth:
        hour_loc_nyc = movingaverage2(hour_loc_nyc,3)
        hour_loc_nonyc = movingaverage2(hour_loc_nonyc,3)

        hour_loc_nyc2 = movingaverage2(hour_loc_nyc2,3)
        hour_loc_nonyc2 = movingaverage2(hour_loc_nonyc2,3)

    plt.plot(time_axis,hour_loc_nyc/hour_loc_nonyc,'b',linewidth=2)
    plt.plot(time_axis,hour_loc_nyc2/hour_loc_nonyc2,'r',linewidth=2)
    
    plt.xlim([0,24])
    plt.ylim(ymin=0)
    plt.xlabel('Hour',fontsize=12)
    plt.ylabel('Normalized photo density',fontsize=12)
    plt.title(allLocNames[i])
# Out:
# number of photos near location  2534
# number of photos near location  2961
# number of photos near location
#  2385
# number of photos near location  8693
# number of photos near location
#  2492
# number of photos near location  3550
# number of photos near location
#  1687
# number of photos near location  1568
# number of photos near location
#  803
# number of photos near location  492
# number of photos near location
#  1138
# number of photos near location  4139
# number of photos near location
#  1665
# number of photos near location  4527

# %%
# get normalizer -- better way to do it but this is fast 
favorites_loc = get_favcounts_sql(db, loc, radius=0.01)
favorites_loc['dayofweek'] = favorites_loc.index.dayofweek
temp = favorites_loc.Fav[(favorites_loc['Fav']>0) & (favorites_loc['dayofweek']>=5)]\
        .groupby(lambda x: (x.hour, x.minute))

temp2 = favorites_loc.Fav.groupby(lambda x: (x.hour, x.minute)).count()
normalizer = pd.Series(np.ones(48),index=temp2.index)
#temp.count()/normalizer
# Out:
# 14184

# %%
# test smoothing function 
from scipy.ndimage import convolve

# regular convolution in numpy -- doesn't have circular
def movingaverage(interval, window_size):
    window= np.ones(int(window_size))/float(window_size)
    return np.convolve(interval, window, 'same')

# cconv can be gotten from scipy
def movingaverage2(interval, window_size):
    window= np.ones(int(window_size))/float(window_size)
    return convolve(interval, window, mode='wrap')

hour_loc = get_hour_mean(photos2,[40.74844,-73.985664],normalize=normalize)/hour_all
hour_loc_av = movingaverage(hour_loc, 3)
hour_loc_av2 = movingaverage2(hour_loc, 3)
fig = plt.figure(figsize=(6,3))
plt.plot(time_axis,hour_loc,'k')
#plt.plot(time_axis,hour_loc_av,'r')
plt.plot(time_axis,hour_loc_av2,'b')
# Out:
# number of photos near location  6192

# %%
# test gaussian weighting function 
def gauss2(X, r0=(0,0), sigma=1):
    rad_sq = np.sum(np.square(np.array(X)-np.array(r0)))
    return math.exp(-(rad_sq)/(2*sigma**2))

def gauss(X, r0=0, sigma=1):
    return math.exp(-(X-r0)**2/(2*sigma**2))

fig = plt.figure(figsize=(6,3))
x = linspace(-3,3,50)
plt.plot(x, [gauss(y) for y in x])
plt.plot(x, [gauss2((0,y)) for y in x],'r')

# %% [markdown]
# # Looking at user location to find photo score differences

# %%
# get unique users who have taken photos in nyc
unique_users = photos2['user_id'].unique()
len(unique_users)
# Out:
# 11929

# %%
import flickr
# get unique locations for all unique users 
user_id = unique_users[100]
method = 'flickr.people.getInfo'
data = flickr._doget(method, user_id=user_id)
loc = data.rsp.person.location.text
print loc
# Out:
# San Francisco, USA

# %%
# determine whether users are based in nyc 

with open('nyc_user_location.json') as fp:
    user_locations = json.load(fp)
print len(user_locations)
unique_locs = unique(user_locations.values())
print 'unique locs ', len(unique_locs)

nyc_token = ['New York, NY', 'New York, New York', 'NYC', 'New York City', 'Brooklyn', 'BROOOOOOOOOKLYNNNN', 'BKYN', \
             'Queens', 'Manhattan', 'Astoria', 'Bronx', 'Bushwick', 'Forest Hills', "Hell's Kitchen", 'Hoboken',\
             'Jackson Heights', 'Jersey City', 'Long Island', 'Newark', 'Staten Island', 'Bayside', 'Harlem', 'East Village',\
             'New York , NY', 'New York NY', 'New York,  New York', 'New York,  NY', 'New York, US', 'New York, U.', \
             'New York, United States', 'New York, the U S of A', 'Newyork, USA']

# beware of Manhattan Beach
# NEW YORK only, NY, U.SA, New York, United, 
def contains_any(s):
    s_lower = s.lower()
    token_checker = [True if token.lower() in s_lower else False for token in nyc_token]
    token_checker.append((s_lower == 'new york') or (s_lower == 'new york ') or (s_lower == 'new york , usa') or \
                         (s_lower == 'new york, usa') or (s_lower == 'ny, usa') or (s_lower == 'ny'))
    return any(token_checker)

# of all the unique locaitons, how many are nyc 
isnyc = np.array([contains_any(user_locations[p]) for p in user_locations])
print sum(isnyc==True)

# of all the photos, how many are taken by those in nyc
isnyc = np.array([True if contains_any(user_locations[p]) else False for p in photos2['user_id'] ])
print sum(isnyc), len(isnyc)

print_locs = False
if print_locs:
    for loc in unique_locs:
        isnyc = contains_any(loc)
        if isnyc:
            print 'TRUE-----> \tlocation:', loc
        else:
            print 'False \tlocation:', loc
# Out:
# 11929
# unique locs  3104
# 1709
# 106826
#  253579

# %% [markdown]
# # Load time scores from database and examine

# %%
import pymysql as mdb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
db = mdb.connect('localhost', 'root', '', 'insight')
with db:
    cur = db.cursor(mdb.cursors.DictCursor)
    cur.execute("SELECT * FROM flickr_clusters_nyc2")
    scores =cur.fetchall()
scores = pd.DataFrame(scores)
time_axis = np.linspace(0,24,49)
time_axis = time_axis[:-1]
hour_keys = [str(x) for x in  np.linspace(0,24,49)]
hour_keys = hour_keys[:-1]

scores['nycscore'] = scores['nphotos_nyc']/scores['nphotos']
scores2 = scores.sort('nycscore',ascending=False)
scores2[['lat','lng','nycscore']].head(n=10)
# Out:
#         lat      lng  nycscore
# 3   40.6832 -73.9737  0.959979
# 66  40.6828 -73.9757  0.955839
# 56  40.7245 -74.0455  0.921703
# 59  40.7487 -73.9197  0.848485
# 46  40.6925 -73.9659  0.695697
# 50  40.7258 -73.9803  0.639427
# 53  40.7042 -73.9867  0.612092
# 28  40.7947 -73.9719  0.598015
# 45  40.6736 -73.9917  0.590810
# 27  40.7025 -73.9886  0.566252

# %%
# Look at the different time scores for the different locations saved in sql
db = mdb.connect('localhost', 'root', '', 'insight')
with db:
    cur = db.cursor(mdb.cursors.DictCursor)
    cur.execute("SELECT * FROM flickr_clusters_nyc2_nycusers")
    scores_nyc = cur.fetchall()
    cur.execute("SELECT * FROM flickr_clusters_nyc2_outusers")
    scores_out = cur.fetchall()
    cur.execute("SELECT * FROM flickr_clusters_nyc2")
    scores =cur.fetchall()

scores_nyc = pd.DataFrame(scores_nyc)
scores_out = pd.DataFrame(scores_out)
scores = pd.DataFrame(scores)
scores = scores.sort('nphotos',ascending=False)
time_axis = np.linspace(0,24,49)
time_axis = time_axis[:-1]

hour_keys = [str(x) for x in  np.linspace(0,24,49)]
hour_keys = hour_keys[:-1]

fig = plt.figure(figsize=(16,16))
for i in range(72):#scores.shape[0]
    ax = fig.add_subplot(9,8,i+1)
    #plt.plot(time_axis, scores_nyc.ix[i][hour_keys]*100,'b')
    #plt.plot(time_axis, scores_out.ix[i][hour_keys]*100,'r')
    plt.plot(time_axis, scores.ix[i][hour_keys]*100,'k')
    #print scores.ix[i][['index','lat','lng']].values
    plt.ylim(ymin=0)
    plt.title('%d'%i)
    #print '%s: %s,%s'%(i, scores['lat'][i], scores['lng'][i])
#fig.set_size_inches(16,16)
#plt.savefig('time_score.png',dpi=100)

# %%
scores[hour_keys].divide(scores[hour_keys].max(axis=1), axis=0).ix[range(72)].head()
#scores.ix[0][hour_keys]
# Out:
#         0.0       0.5       1.0       1.5       2.0       2.5       3.0  \
# 0  0.924240  0.958757  0.981284  0.916332  0.872211  0.860827  0.885716
# 1  0.831930  0.842882  0.805924  0.825959  0.851546  1.000000  0.864304
# 2  1.000000  0.932787  0.784572  0.628975  0.545622  0.557188  0.541020
# 3  0.375151  0.434756  0.519071  0.589400  0.675913  0.746692  0.819242
# 4  0.389603  0.437839  0.415939  0.450772  0.468447  0.592899  0.669387
#
#         3.5       4.0       4.5    ...         19.0      19.5      20.0  \
# 0  0.889304  0.770424  0.694830    ...     0.841879  0.843304  0.863310
# 1  0.803502  0.676944  0.819226    ...     0.784720  0.768617  0.762629
# 2  0.604650  0.585992  0.498567    ...     0.580292  0.627770  0.651421
# 3  0.864152  0.922509  0.974326    ...     0.166617  0.176203  0.190711
# 4  0.762476  0.675834  0.620998    ...     0.458384  0.410194  0.356368
#
#        20.5      21.0      21.5      22.0      22.5      23.0      23.5
# ...

# %%
# clustering to determine location types 
from sklearn import decomposition
from mpl_toolkits.mplot3d import Axes3D
np.random.seed(5)

#data = scores[hour_keys].values
#data = scores[hour_keys].ix[range(72)].values
data = scores[hour_keys].divide(scores[hour_keys].max(axis=1), axis=0).ix[range(72)].values
latlng = scores[['index','lat','lng']].ix[range(72)].values
pca = decomposition.PCA(n_components=3)
pca.fit(data)
print(pca.explained_variance_ratio_) 
X = pca.transform(data)

fig = plt.figure(1, figsize=(5, 5))
scatter(X[:, 0], X[:, 1])
ind = 10
#plt.plot(X[ind,0], X[ind,1],'or')
# plt.clf()
# ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
# ax.scatter(X[:, 0], X[:, 1], X[:, 2], cmap=plt.cm.spectral)
plt.show()
sorted_inds = X[:,1].argsort()
print sorted_inds # lowest to highest
# 12=moma, rockefeller, prince street, river cafe 
#plt.plot(time_axis, data*100,'k')
for btm_pc in sorted_inds[:5]:
    plt.plot(time_axis,data[btm_pc,:])
    print latlng[btm_pc,:]
# Out:
# [ 0.45346458  0.22236401  0.14791246]
# [69 24 70 59 44 56  8  4 46 19 25  7 18 36 35 62 53 16 28 27 64 40 34 33 23
#  13 10  9 17 29 48 20 30 71 65 15 49 11 58 51 12  0 38 55 60 41 52 31 61 57
#  63  2 68 22 54 39 67  1 26 42 50 43 37 45 32  5  6 21 47 14  3 66]
# [ 69.      40.8649 -73.932 ]
# [ 24.      40.6707 -73.966 ]
# [ 70.      40.7497 -73.8467]
# [ 59.      40.7487 -73.9197]
# [ 44.      40.6871 -73.9912]

# %%
# which locations have the biggest difference between nyc and nonnyc users
init_loc = [40.74844,-73.985664]
centroids_full = get_centroids_timescore_sql(db,init_loc,maxdist=0.5,num=200)
centroids_full = pd.DataFrame(centroids_full)
centroids_full['nycscore'] = centroids_full['nphotos_nyc'] / centroids_full['nphotos']
centroids_full = centroids_full.sort('nycscore',ascending=False, kind='mergesort')
centroids_full[['lat','lng']].head(n=20)
# 62,63, atlantic ave, 
# 28 - Tompkins Square Park in EV 
# 48 under Manhattan bridge 
# 44 - Williamsburg
# 49 Main street park in dubmo
# 65 Brooklyn Museum
# Out:
#         lat      lng
# 62  40.6832 -73.9737
# 63  40.6828 -73.9757
# 60  40.7245 -74.0455
# 61  40.7487 -73.9197
# 57  40.6925 -73.9659
# 28  40.7258 -73.9803
# 48  40.7042 -73.9867
# 55  40.7947 -73.9719
# 64  40.6736 -73.9917
# 52  40.7025 -73.9886
# 44  40.7178 -73.9578
# 49  40.7044 -73.9903
# 50  40.7032 -73.9905
# 19  40.7292 -73.9883
# 40  40.7192 -73.9617
# 65  40.6707 -73.9660
# 24  40.7282 -73.9910
# 14  40.7317 -73.9894
# 42  40.7218 -73.9577
# 23  40.7296 -73.9937

# %%
# looking visiting duration 
with db:
    cur = db.cursor(mdb.cursors.DictCursor)
    cmd = "SELECT ClusterId, lat, lng, Dur FROM flickr_clusters_nyc2_visitdur JOIN flickr_clusters_nyc2 \
    ON flickr_clusters_nyc2_visitdur.ClusterId = flickr_clusters_nyc2.index" 
    cur.execute(cmd)
    centroids = cur.fetchall()
centroids = pd.DataFrame(centroids)
centroids['Dur_hour'] = centroids['Dur']/3600.
result = centroids.sort(['Dur'], ascending=False)
result.head(n=10)
# Out:
#     ClusterId    Dur      lat      lng  Dur_hour
# 59         59  10056  40.7487 -73.9197  2.793333
# 4           4   7664  40.7575 -74.0023  2.128889
# 14         14   7476  40.6517 -73.7159  2.076667
# 46         46   7267  40.6925 -73.9659  2.018611
# 51         51   6514  40.8295 -73.9267  1.809444
# 70         70   6494  40.7497 -73.8467  1.803889
# 20         20   5695  40.7569 -73.8460  1.581944
# 44         44   5631  40.6871 -73.9912  1.564167
# 56         56   5382  40.7245 -74.0455  1.495000
# 55         55   5256  40.7523 -73.9936  1.460000

# %% [markdown]
# # Now Switch to looking at the correlation of these three measures

# %%
cd flask_site/app/
# Out:
# /Users/Helena/Projects/Insight/flask_site/app

# %%
# write a function for getting the favorite counts at a location by doing a join
import pymysql as mdb
db = mdb.connect('localhost', 'root', '', 'insight')
def get_favcounts_sql(db,init_loc,lim=0.005):
    with db:
        cur = db.cursor(mdb.cursors.DictCursor)
        cmd = "SELECT flickr_favorites.Id,Fav,Lat,Lng FROM flickr_yahoo_nyc JOIN flickr_favorites \
        ON flickr_yahoo_nyc.Id = flickr_favorites.Id\
        WHERE ((lat BETWEEN %s AND %s) AND (lng BETWEEN %s AND %s))" % \
        (init_loc[0]-lim,init_loc[0]+lim,init_loc[1]-lim,init_loc[1]+lim)
        cur.execute(cmd)
        results = cur.fetchall()
    return results

fav_counts = pd.DataFrame(get_favcounts_sql(db, [40.74844,-73.985664]))
fav_counts.head()
fav_counts['Fav'].describe()
# Out:
# count    9635.000000
# mean        0.886663
# std         6.153917
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       236.000000
# dtype: float64

# %%
# different way to calculate favorite counts 
# use the reduced data set with duplicate users taken out for each half hour interval
# user the cluster labels to restrict photos 
def get_favcounts_sql2(db,clusterid):
    with db:
        cur = db.cursor(mdb.cursors.DictCursor)
        cmd = "SELECT flickr_favorites.Id, Fav FROM flickr_yahoo_nyc2 JOIN flickr_favorites \
        ON flickr_yahoo_nyc2.Id = flickr_favorites.Id\
        WHERE cluster_label = %d" % clusterid
        cur.execute(cmd)
        results = cur.fetchall()
    return results

fav_counts = get_favcounts_sql2(db,0)
fav_counts = pd.DataFrame(fav_counts)
fav_counts.head()
#print fav_counts['Fav'].describe()
# Out:
#    Fav           Id
# 0    0  10018714265
# 1    1  10025157614
# 2    0  10038445256
# 3    0  10045286163
# 4    0  10056439844

# %%
def get_tripadvisor_sql(db,lat,lng,lim=0.005):
    with db:
        cur = db.cursor(mdb.cursors.DictCursor)
        cmd = "SELECT * FROM tripadvisor JOIN tripadvisor_latlng \
               ON tripadvisor.Id = tripadvisor_latlng.Id \
               WHERE ((loc_lat BETWEEN %s AND %s) AND (loc_lng BETWEEN %s AND %s))" %\
               (lat-lim/2,lat+lim/2,lng-lim/2,lng+lim/2)
        cur.execute(cmd)
        attractions = cur.fetchall()
    return attractions

# gaussian weighting function for approximity to tourist location 
def _gauss2(X, r0=(0,0), sigma=1):
    rad_sq = _dist_squared(X,r0)
    return math.exp(-(rad_sq)/(2*sigma**2))

def _dist_squared(x,y):
    return np.sum(np.square(np.array(x)-np.array(y)))

# get rid of duplicate attractions (those with multiple google lookups by taking their mean coordinates)
def remove_attraction_duplicates(attractions):
    attractions = pd.DataFrame(attractions)
    attractions = attractions.groupby('name').mean()
    #print attractions['Id']
    attractions = attractions.reset_index()
    return attractions.T.to_dict().values()

# TODO: need to get rid of duplicate locations! take their average!!! 
def touristy_score(location, attractions, remove_duplicates=True, doRating=0):
    if doRating == 1: # by rating 
        landmark_score = lambda att: att['rating'] if att['rating'] is not None else 0
        multiplier = 1
        
    elif doRating == 2: # by nothing 
        landmark_score = lambda att: 1
        multiplier = 1
        
    else: # by inverse ranking
        print 'by ranking'
        landmark_score = lambda att: 1./(att['Id']+1)
        multiplier = 100
        
    if len(attractions) > 0:
        if remove_duplicates:
            attractions = remove_attraction_duplicates(attractions)
            #print 'reduced len', len(attractions)
        dist_weight = [ landmark_score(att) * _gauss2( (att['loc_lat'], att['loc_lng']),  location, sigma=0.15/69) \
        for att in attractions]
        #print dist_weight
        return multiplier*np.nanmean(dist_weight)
    else:
        return 0

# test
curr_loc = [40.74844,-73.985664]
attractions = get_tripadvisor_sql(db,curr_loc[0],curr_loc[1],lim=0.01)
#print pd.DataFrame(attractions)['rating']
score = touristy_score(curr_loc, attractions, doRating=0)
print score
# Out:
# by ranking
# 0.858510170493

# %%
# load trip advisor attractions and their coordinates 
# compare trip advisor durations 
with db:
    cur = db.cursor(mdb.cursors.DictCursor)
    cur.execute("SELECT Id, length FROM tripadvisor")
    attractions = cur.fetchall()
    cur.execute("SELECT * FROM tripadvisor_latlng")
    attractions_latlng = cur.fetchall()

# get their durations 
strings = {'More than 3 hours': 3.5, '1-2 hours': 1.5, '2-3 hours': 2.5}
attr_dur = []
for attr in attractions:
    curr_str = attr['length'].rstrip(' ')
    if (curr_str == 'null') or (curr_str == ''):
        attr_dur.append(None)
    elif curr_str in strings:
        attr_dur.append(strings[curr_str])
    else:
        print curr_str
        pdb.set_trace()

attractions = pd.DataFrame(attractions)
attractions_latlng = pd.DataFrame(attractions_latlng)
attractions['duration'] = attr_dur
#attractions['duration'].hist()
attractions = attractions.ix[attractions['duration'].notnull()]
#print attractions.head()
#print attractions_latlng.head()

# load all centroids 
with db:
    cur = db.cursor(mdb.cursors.DictCursor)
    cmd = "SELECT * FROM flickr_clusters_nyc2 JOIN flickr_clusters_nyc2_visitdur\
    WHERE flickr_clusters_nyc2.index = flickr_clusters_nyc2_visitdur.ClusterId"
    cur.execute(cmd)
    centroids = cur.fetchall()
centroids = pd.DataFrame(centroids)

dur1 = []
dur2 = []

# compare to our durations 
for idx, attr in attractions.iterrows():
    #print idx 
    #attr = attractions.ix[idx]
    # get attraction coordinates
    curr_idx = attractions_latlng['Id'] == attr.Id
    curr_location = attractions_latlng[['loc_lat', 'loc_lng']][curr_idx].mean()
    # find the nearest centroid
    centroids['dist'] = (centroids['lat']-curr_location['loc_lat'])**2 + (centroids['lng'] - curr_location['loc_lng'])**2
    result = centroids.sort('dist')
    # get the duration for that centroid
    centroid_dur = result.head(n=10)['Dur'].mean()/3600.0
    dur1.append(attr['duration'])
    dur2.append(centroid_dur)
plt.plot(dur1, dur2, 'o')
print pearsonr(dur1, dur2)
# plt.yscale('log')
# plt.xscale('log')
# Out:
# (-0.23665306367147268, 0.15257154520975616)

# %%
# %reload_ext autoreload
# get all three measures for each cluster 
from flickr_sites import *
#from tripomatic_lookup import *
from scipy.stats import pearsonr
# test correlation between photo density and touristiness score 

db = mdb.connect('localhost', 'root', '', 'insight')
#curr_loc = [40.74844,-73.985664]
# get all possible attractions 
#attractions = get_tripomatic_sql(db,curr_loc[0],curr_loc[1],lim=0.5)
#print len(attractions), 'attractions'

# load all centroids 
with db:
    cur = db.cursor(mdb.cursors.DictCursor)
    cmd = "SELECT * FROM flickr_clusters_nyc2"
    cur.execute(cmd)
    centroids = cur.fetchall()

all_score = []
all_density = []
all_fav = []
for cent in centroids:
    curr_loc = (cent['lat'],cent['lng'])
    # attractions within neighborhood
    #attractions = get_tripomatic_sql(db,curr_loc[0],curr_loc[1],lim=0.01)
    attractions = get_tripadvisor_sql(db,curr_loc[0], curr_loc[1], lim=0.01)
    # touristiness score
    try: 
        #tripomatic_score = touristy_score(curr_loc, attractions, rank_score=True)
        tripomatic_score = touristy_score(curr_loc, attractions, doRating=0)
    except Exception as e:
        print e
        tripomatic_score = 0
    
    # photo density 
    #photos = get_heatmap_sql(db,curr_loc,lim=0.005)
    #photo_density = len(photos)
    photo_density = cent['nphotos']
    
    # average favorite count for this location
    favs = get_favcounts_sql(db, curr_loc)
    #favs = get_favcounts_sql2(db, cent['index'])
    print cent['index'], len(favs)
    if favs:
        fav_counts = pd.DataFrame(favs)
        all_fav.append(fav_counts['Fav'].mean())
    else:
        all_fav.append(0.)

    #print photo_density, tripomatic_score
    all_density.append(photo_density)
    all_score.append(tripomatic_score)

all_score = np.array(all_score)
all_density = np.array(all_density)
all_fav = np.array(all_fav)
# Out:
# by ranking
# 0
#  15578
# by ranking
# 1
#  5821
# by ranking
# 2
#  3473
# by ranking
# 3
#  70487
# by ranking
# 4
#  4891
# by ranking
# 5
#  6806
# by ranking
# 6
#  14881
# by ranking
# 7
#  9073
# by ranking
# 8
#  9827
# by ranking
# 9
#  9287
# by ranking
# 10
#  10797
# by ranking
# 11
#  7986
# by ranking
# 12
#  15448
# by ranking
# 13
#  9480
# by ranking
# 14
#  3100
# by ranking
# 15
#  9556
# by ranking
# 16
#  9036
# by ranking
# 17
#  6598
# by ranking
# 18
#  1221
# by ranking
# 19
#  6841
# by ranking
# 20
#  257
# by ranking
# 21
#  9876
# by ranking
# 22
#  4429
# by ranking
# 23
#  9303
# by ranking
# 24
#  7045
# by ranking
# 25
#  4458
# by ranking
# 26
#  9862
# by ranking
# 27
#  3675
# by ranking
# 28
#  1703
# by ranking
# 29
#  8875
# by ranking
# 30
#  9630
# by ranking
# 31
#  7739
# by ranking
# 32
#  15656
# by ranking
# 33
#  5942
# by ranking
# 34
#  1469
# by ranking
# 35
#  8624
# by ranking
# 36
#  5162
# by ranking
# 37
#  3170
# by ranking
# ...

# %%
# plt.plot(all_score, allmetrics['score'], 'o')
# plt.yscale('log')
# plt.xscale('log')
# print pearsonr(np.log(all_density),np.log(all_score+1))
#print pd.DataFrame(attractions)['rating']

# %%
# plot shit 
fig = plt.figure(figsize=(16,4))
ax = fig.add_subplot(131)
plt.plot(all_density,all_score,'o')
plt.yscale('log')
plt.xscale('log')
plt.xlabel('photo density')
plt.ylabel('touristy score')
#np.corrcoef(np.log(all_density),np.log(np.array(all_score)+1))
print pearsonr(np.log(all_density),np.log(all_score+1))

ax = fig.add_subplot(132)
plt.plot(all_density,all_fav,'o')
plt.yscale('log')
plt.xscale('log')
plt.xlabel('photo density')
plt.ylabel('favorite counts')
print pearsonr(np.log(all_density),np.log(all_fav+1))

ax = fig.add_subplot(133)
plt.plot(all_score,all_fav,'o')
plt.yscale('log')
plt.xscale('log')
plt.xlabel('touristy score')
plt.ylabel('favorite counts')
print pearsonr(np.log(all_score+1), np.log(all_fav+1))
# Out:
# (0.21499186391227842, 0.0697376872752965)
# (0.06878007385562214, 0.56591053290079796)
# (0.14945072107575416, 0.21021008619383941)

# %%
import seaborn as sns
#fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
#plt.plot(all_density,all_score,'o',ms=8)#markeredgecolor=[1,1,1,1],lw=5
sns.lmplot('density', 'score', allmetrics, palette="Set1", fit_reg=False, size=5, scatter_kws={'s': 80});
plt.yscale('log')
plt.xscale('log')
plt.xlim([200,50000])
plt.ylim([0.005, 500])
#plt.xlabel('Log photo density', fontsize=18, fontname='sans-serif',weight='light')
#plt.ylabel('Log touristiness score',fontsize=18, fontname='sans-serif', weight='light')
plt.xticks(fontsize=18, fontname='sans-serif')
plt.yticks(fontsize=18, fontname='sans-serif')
#ax.set_frame_on(False)
#savefig('tripomatic_corr3.eps', format='eps', bbox_inches='tight')
savefig('tripadvisor_corr2.png',bbox_inches='tight')
#color = sns.color_palette()[2]

# %%
# distribution of favorite counts 
fig = plt.figure(figsize=(8,4))
plt.hist(all_fav,bins=20)
# Out:
# (array([ 30.,  10.,  11.,   6.,   7.,   0.,   3.,   0.,   0.,   0.,   1.,
#           0.,   1.,   1.,   0.,   1.,   0.,   0.,   0.,   1.]),
#  array([ 0.        ,  0.38653846,  0.77307692,  1.15961538,  1.54615385,
#          1.93269231,  2.31923077,  2.70576923,  3.09230769,  3.47884615,
#          3.86538462,  4.25192308,  4.63846154,  5.025     ,  5.41153846,
#          5.79807692,  6.18461538,  6.57115385,  6.95769231,  7.34423077,
#          7.73076923]),
#  <a list of 20 Patch objects>)

# %%
allmetrics = pd.DataFrame([all_density, all_score, all_fav])
allmetrics = allmetrics.T
allmetrics.columns = ['density','score','fav']
allmetrics.head()
print allmetrics['score'][allmetrics.density > 10000]
# Out:
# 3      0.000000
# 6     23.323426
# 12     9.377087
# 66     0.000000
# Name: score, dtype: float64

# %%
curr_loc = [40.74844,-73.985664]
radius = 0.005
idx = (photos2['lat']-curr_loc[0])**2 + (photos2['lng']-curr_loc[1])**2 < radius ** 2
smallset  = photos2.ix[idx]
smallset2 = photos2.ix[idx == False]
inside_area = smallset['date_taken'].groupby((lambda x: x.date(), smallset['user_id'])).first()
outside_area = smallset2['date_taken'].groupby((lambda x: x.date(), smallset2['user_id'])).first()
inside_area.name = 'inside_start'
outside_area.name = 'outside_start'
inside_area = inside_area.reset_index()
outside_area = outside_area.reset_index()

print inside_area.head()
print outside_area.head()

# hour_mean = photo_df.user_id[idx].groupby(lambda x: (x.hour, x.minute)).count()
#photos2.groupby('user_name')['date_taken'].first()
# smallset['date_taken']
# Out:
#       level_0       user_id        inside_start
# 0  2009-01-01  24468935@N03 2009-01-01 08:00:00
# 1  2009-01-01  29640494@N07 2009-01-01 11:30:00
# 2  2009-01-02  35091267@N04 2009-01-02 09:30:00
# 3  2009-01-02  60888189@N00 2009-01-02 20:00:00
# 4  2009-01-02  99842842@N00 2009-01-02 11:30:00
#       level_0       user_id       outside_start
# 0  2009-01-01  10304090@N08 2009-01-01 00:30:00
# 1  2009-01-01  10345599@N03 2009-01-01 14:30:00
# 2  2009-01-01  10990944@N07 2009-01-01 19:00:00
# 3  2009-01-01  11960451@N04 2009-01-01 15:30:00
# 4  2009-01-01  13101981@N03 2009-01-01 19:00:00

# %%
print photos2.shape
combined = pd.merge(inside_area, outside_area, how='inner', on=['level_0', 'user_id'])
print combined.shape
print inside_area.shape
print outside_area.shape
combined.head()
timediff = combined['outside_start']-combined['inside_start']

median(timediff[(timediff>0) & (timediff<np.timedelta64(8, 'h'))])/np.timedelta64(1, 's')/3600.
# Out:
# (253579, 25)
# (2193, 4)
# (4272, 3)
# (117353, 3)
# 2.5

# %%
# Places with the highest photo densities 
densities = [(d, (cent['lat'], cent['lng'])) for d, cent in zip(all_density, centroids)]
densities = pd.DataFrame(densities,columns=['density', 'lat_lng'])
densities.sort('density', ascending=False).head(n=10)
# top five: 
# 66, 3, atlantic terminal/Barclay x 2
# 6, time square
# 12, MOMA
# 32, Bryant Park
# 0, Rockefeller Ctr
# 67, World trade ctr 
# 63, Broadway, near the empire state building? in front?
# Out:
#     density              lat_lng
# 66    13700  (40.6828, -73.9757)
# 3     13543  (40.6832, -73.9737)
# 6     11341  (40.7574, -73.9859)
# 12    10650   (40.7612, -73.977)
# 32     9961  (40.7541, -73.9839)
# 0      9747  (40.7591, -73.9791)
# 67     8522  (40.7122, -74.0099)
# 63     8369  (40.7458, -73.9881)
# 10     7333  (40.7261, -73.9958)
# 21     7134  (40.7561, -73.9902)

# %%
# Places with the highest touristy score 
scores = [(d, (cent['lat'], cent['lng'])) for d, cent in zip(all_score, centroids)]
scores = pd.DataFrame(scores, columns=['scores', 'lat_lng'])
scores.sort('scores', ascending=False).head(n=10)
# 15, liberty park
# 48, wall street
# 67, world trade center
# 38, world trade center inside
# 6, time square 
# 0, rockefeller center 
# 39, empire state building
# 12, MOMA
# 28, Herald square 
# 11, Grand central
# Out:
#         scores              lat_lng
# 15  147.165252  (40.7093, -74.0112)
# 48  104.821975   (40.7073, -74.011)
# 67   67.148595  (40.7122, -74.0099)
# 38   55.911407  (40.7116, -74.0129)
# 6    33.418127  (40.7574, -73.9859)
# 0    18.866760  (40.7591, -73.9791)
# 39   18.775011  (40.7484, -73.9855)
# 12   13.093692   (40.7612, -73.977)
# 26   10.310962  (40.7499, -73.9878)
# 11    9.019672  (40.7526, -73.9772)

# %%
# Places with the highest favorites score 
favorites = [(d, (cent['lat'], cent['lng'])) for d, cent in zip(all_fav, centroids)]
favorites = pd.DataFrame(favorites, columns=['favcount', 'lat_lng'])
favorites.sort('favcount', ascending=False).head(n=10)
# 67, World Trade Center 
# 56, Jersey City/ Hoboken -- BAD
# 28, Harlem - random little parky area 
# 5, Chambers Street 
# 50, --72nd street parky area 
# 69, Ford Tryon Park in Riverside
# 22, Brookyn Bridge! 
# 1, Southwest Corner of Central Park (columbus circle)
# 48, Wall street
# Out:
#     favcount              lat_lng
# 67  8.040000  (40.7122, -74.0099)
# 56  6.266667  (40.7245, -74.0455)
# 5   5.432000  (40.7145, -74.0067)
# 28  4.875000  (40.7947, -73.9719)
# 18  4.314286  (40.7792, -73.9817)
# 50  3.400000  (40.7258, -73.9803)
# 69  3.080000   (40.8649, -73.932)
# 1   2.073733   (40.7681, -73.982)
# 22  2.052632  (40.7059, -73.9966)
# 48  1.990291   (40.7073, -74.011)
